# %% [markdown]
# # En France, le député assidu présente-t-il un profil type ?
#
# <p style="text-align:justify";> Alors que la société française se caractérise par une grande défiance de la population vis-à-vis de ses élus et responsables politiques, nous nous pencherons dans ce projet sur la question de l'assiduité des députés au cours de leur mandat. Nous verrons notamment grâce à différents outils (boîtes de Tukey, matrice de nuages de points, analyse en composantes principales, clustering, régression linéaire...) si l'on peut dresser un portrait type pour caractériser le député assidu ou absentéiste.

# %%
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## I. Récupération et préparation des données
#
# ### 1. Importation des données
#
# <p style="text-align:justify";>On récupère sur le site citoyen nosdeputes.fr une base de données synthétisant l'activité parlementaire sur les 12 derniers mois. Pour chaque député, cette table, que nous avons convertie au format .tsv, contient des informations relatives à son état civil, à la circonscription dont il est le représentant, à son éventuel parti politique et surtout à son travail parlementaire (semaines de présence à l'Assemblée nationale, rédaction de rapports, participation à des commissions...).

# %%
# Conversion du fichier tsv en DataFrame.
df = pd.read_csv("C:/Users/theop/Documents/nosdeputes.fr_synthese_2020-10-24.tsv", sep='\t')
df
# Out:
#       id                              nom        nom_de_famille  \
# 0     32                      Damien Abad                  Abad
# 1     43                  Caroline Abadie                Abadie
# 2    493             Jean-Félix Acquaviva             Acquaviva
# 3    152                     Lénaïck Adam                  Adam
# 4    234                      Damien Adam                  Adam
# 5    135                     Saïd Ahamada               Ahamada
# 6    508                     Éric Alauzet               Alauzet
# 7    183                      Ramlati Ali                   Ali
# 8    499                      Aude Amadou                Amadou
# 9    382                    Patrice Anato                 Anato
# 10   441         Pieyre-Alexandre Anglade               Anglade
# 11    11              Emmanuelle Anthoine              Anthoine
# 12   564            Jean-Philippe Ardouin               Ardouin
# 13   220                 Christophe Arend                 Arend
# 14   604                  Stéphanie Atger                 Atger
# 15   332                    Julien Aubert                Aubert
# 16   406                   Sophie Auconie               Auconie
# 17   404                Clémentine Autain                Autain
# 18   461                    Laetitia Avia                  Avia
# 19    52                   Joël Aviragnet             Aviragnet
# 20   121                Florian Bachelier             Bachelier
# 21    59                 Delphine Bagarry               Bagarry
# 22   488                  Didier Baichère              Baichère
# 23   323                   Erwan Balanant              Balanant
# 24    41                Géraldine Bannier               Bannier
# 25   358                 Frédéric Barbier               Barbier
# 26   106                 Jean-Noël Barrot                Barrot
# 27   217                 Nathalie Bassire               Bassire
# 28   500                   Delphine Batho                 Batho
# 29   209           Marie-Noëlle Battistel             Battistel
# ..   ...                              ...                   ...
# 509  491      Hélène Vainqueur-Christophe  Vainqueur-Christophe
# 510  140                Isabelle Valentin              Valentin
# 511  133       Alexandra Valetta Ardisson      Valetta Ardisson
# 512   76                    Boris Vallaud               Vallaud
# 513  162           Laurence Vanceunebrock         Vanceunebrock
# 514   44                     Pierre Vatin                 Vatin
# 515  417           Michèle de Vaucouleurs      Vaucouleurs (de)
# 516  607                   Pierre Venteau               Venteau
# 517  244  Marie-Christine Verdier-Jouclas       Verdier-Jouclas
# 518  226                     Arnaud Viala                 Viala
# 519  542                    Michel Vialay                Vialay
# 520   13             Laurence Vichnievsky           Vichnievsky
# 521  587                  Michèle Victory               Victory
# 522  175                      Annie Vidal                 Vidal
# 523  116                  Philippe Vigier                Vigier
# 524  202               Jean-Pierre Vigier                Vigier
# 525  293                   Patrick Vignal                Vignal
# 526  258                   Corinne Vignon                Vignon
# 527  535                   Cédric Villani               Villani
# 528  434                   André Villiers              Villiers
# 529  551                    Stéphane Viry                  Viry
# 530    7              Guillaume Vuilletet             Vuilletet
# 531  497                Jean-Luc Warsmann              Warsmann
# 532   48                 Sylvain Waserman              Waserman
# 533  192                      Éric Woerth                Woerth
# 534   26                   Martine Wonner                Wonner
# 535  215                  Hubert Wulfranc              Wulfranc
# 536  130                   Hélène Zannier               Zannier
# 537   31                 Jean-Marc Zulesi                Zulesi
# 538  329                 Michel Zumkeller             Zumkeller
#
#                prenom sexe date_naissance  \
# 0              Damien    H     1980-04-05
# 1            Caroline    F     1976-09-07
# 2          Jean-Félix    H     1973-03-19
# 3             Lénaïck    H     1992-02-19
# 4              Damien    H     1989-06-28
# 5                Saïd    H     1972-11-07
# 6                Éric    H     1958-06-07
# 7             Ramlati    F     1961-05-28
# 8                Aude    F     1980-02-29
# 9             Patrice    H     1976-03-14
# 10   Pieyre-Alexandre    H     1986-11-02
# 11         Emmanuelle    F     1964-07-02
# 12      Jean-Philippe    H     1964-03-05
# 13         Christophe    H     1975-08-12
# 14          Stéphanie    F     1975-10-11
# 15             Julien    H     1978-06-11
# 16             Sophie    F     1963-08-19
# 17         Clémentine    F     1973-05-26
# 18           Laetitia    F     1985-10-29
# 19               Joël    H     1956-06-16
# 20            Florian    H     1979-04-05
# 21           Delphine    F     1970-01-09
# 22             Didier    H     1970-08-20
# 23              Erwan    H     1971-02-21
# 24          Géraldine    F     1979-11-22
# 25           Frédéric    H     1960-08-30
# 26          Jean-Noël    H     1983-05-13
# 27           Nathalie    F     1968-01-22
# 28           Delphine    F     1973-03-23
# 29       Marie-Noëlle    F     1956-08-20
# ..                ...  ...            ...
# 509            Hélène    F     1956-05-06
# 510          Isabelle    F     1962-01-20
# 511         Alexandra    F     1976-06-07
# 512             Boris    H     1975-07-25
# 513          Laurence    F     1970-05-06
# 514            Pierre    H     1967-08-21
# 515           Michèle    F     1964-02-12
# 516            Pierre    H     1974-08-26
# 517   Marie-Christine    F     1965-03-19
# 518            Arnaud    H     1974-12-04
# 519            Michel    H     1960-01-06
# 520          Laurence    F     1955-02-05
# 521           Michèle    F     1958-10-28
# 522             Annie    F     1956-09-17
# 523          Philippe    H     1958-02-03
# 524       Jean-Pierre    H     1969-10-22
# 525           Patrick    H     1958-01-22
# 526           Corinne    F     1963-06-10
# 527            Cédric    H     1973-10-05
# 528             André    H     1954-12-13
# 529          Stéphane    H     1969-10-14
# 530         Guillaume    H     1967-06-20
# 531          Jean-Luc    H     1965-10-22
# 532           Sylvain    H     1967-12-08
# 533              Éric    H     1956-01-29
# 534           Martine    F     1964-03-27
# 535            Hubert    H     1956-12-17
# 536            Hélène    F     1972-09-19
# 537         Jean-Marc    H     1988-06-06
# 538            Michel    H     1966-01-21
#
#                             lieu_naissance num_deptmt  \
# 0                             Nîmes (Gard)         01
# 1             Saint-Martin-d'Hères (Isère)         38
# 2                     Bastia (Haute-Corse)         2B
# 3         Saint Laurent du Maroni (Guyane)        973
# 4                         Orléans (Loiret)         76
# 5                    Saint-Denis (Réunion)         13
# 6               Nancy (Meurthe-et-Moselle)         25
# 7                       Pamandzi (Mayotte)        976
# 8                       Coutances (Manche)         44
# 9                              Lomé (Togo)         93
# 10                        Paris 16 (Paris)        999
# 11                   Saint-Vallier (Drôme)         26
# 12             Saintes (Charente-Maritime)         17
# 13                       Forbach (Moselle)         57
# 14                  Sarcelles (Val-d'Oise)         91
# 15            Marseille (Bouches-du-Rhône)         84
# 16               Dugny (Seine-Saint-Denis)         37
# 17            Saint-Cloud (Hauts-de-Seine)         93
# 18        Livry-Gargan (Seine-Saint-Denis)         75
# 19    Encausse-les-Thermes (Haute-Garonne)         31
# 20                    Thionville (Moselle)         35
# 21                            Lyon (Rhône)         04
# 22                           Limoux (Aude)         78
# 23                      Lorient (Morbihan)         29
# 24                         Laval (Mayenne)         53
# 25                      Audincourt (Doubs)         25
# 26                           Paris (Paris)         78
# 27                  Saint-Pierre (Réunion)        974
# 28                     Paris 12ème (Paris)         79
# 29                        Grenoble (Isère)         38
# ..                                     ...        ...
# 509            Trois-Rivières (Guadeloupe)        971
# 510             Puy-en-Velay (Haute-Loire)         43
# 511               Cannes (Alpes-Maritimes)         06
# 512                       Beyrouth (Liban)         40
# 513                  Avion (Pas-de-Calais)         03
# 514                  Saint-Quentin (Aisne)         60
# 515                   Albertville (Savoie)         78
# 516  Saint-Yrieix-la-Perche (Haute-Vienne)         87
# 517                            Albi (Tarn)         81
# 518                       Millau (Aveyron)         12
# 519                    Paris 20ème (Paris)         78
# 520  Boulogne-Billancourt (Hauts-de-Seine)         63
# 521                         Bône (Algérie)         07
# 522            La Bohalle (Maine-et-Loire)         76
# 523                        Valence (Drôme)         28
# 524                  Brioude (Haute-Loire)         43
# 525                  Montpellier (Hérault)         34
# 526                  Agen (Lot-et-Garonne)         31
# 527                        Brive (Corrèze)         91
# 528                        Avallon (Yonne)         89
# 529                        Épinal (Vosges)         88
# 530                        Beauvais (Oise)         95
# 531             Villers-Semeuse (Ardennes)         08
# 532                       Paris 07 (Paris)         67
# 533                           Creil (Oise)         60
# 534                      Hayange (Moselle)         67
# 535                 Rouen (Seine-Maritime)         76
# 536                  Saint-Avold (Moselle)         57
# 537           Marseille (Bouches-du-Rhône)         13
# 538        Belfort (Territoire de Belfort)         90
#
#                            nom_circo  num_circo  ... hemicycle_interventions  \
# 0                                Ain          5  ...                     253
# 1                              Isère          8  ...                      17
# 2                        Haute-Corse          2  ...                     109
# 3                             Guyane          2  ...                       3
# 4                     Seine-Maritime          1  ...                      24
# 5                   Bouches-du-Rhône          7  ...                       8
# 6                              Doubs          2  ...                       3
# 7                            Mayotte          1  ...                       5
# 8                   Loire-Atlantique          4  ...                       2
# 9                  Seine-Saint-Denis          3  ...                       5
# 10   Français établis hors de France          4  ...                       8
# 11                             Drôme          4  ...                      64
# 12                 Charente-Maritime          3  ...                       4
# 13                           Moselle          6  ...                       1
# 14                           Essonne          6  ...                      19
# 15                          Vaucluse          5  ...                     285
# 16                    Indre-et-Loire          3  ...                     183
# 17                 Seine-Saint-Denis         11  ...                     401
# 18                             Paris          8  ...                     114
# 19                     Haute-Garonne          8  ...                     127
# 20                   Ille-et-Vilaine          8  ...                       7
# 21           Alpes-de-Haute-Provence          1  ...                      55
# 22                          Yvelines          1  ...                      14
# 23                         Finistère          8  ...                     320
# 24                           Mayenne          2  ...                      74
# 25                             Doubs          4  ...                       0
# 26                          Yvelines          2  ...                      93
# 27                           Réunion          3  ...                      14
# 28                       Deux-Sèvres          2  ...                     180
# 29                             Isère          4  ...                     181
# ..                               ...        ...  ...                     ...
# 509                       Guadeloupe          4  ...                      15
# 510                      Haute-Loire          1  ...                      85
# 511                  Alpes-Maritimes          4  ...                       2
# 512                           Landes          3  ...                     376
# 513                           Allier          2  ...                      22
# 514                             Oise          5  ...                      60
# 515                         Yvelines          7  ...                      76
# 516                     Haute-Vienne          2  ...                       1
# 517                             Tarn          2  ...                     185
# 518                          Aveyron          3  ...                     176
# 519                         Yvelines          8  ...                      21
# 520                      Puy-de-Dôme          3  ...                      27
# 521                          Ardèche          2  ...                      92
# 522                   Seine-Maritime          2  ...                      16
# 523                     Eure-et-Loir          4  ...                     278
# 524                      Haute-Loire          2  ...                      65
# 525                          Hérault          9  ...                       0
# 526                    Haute-Garonne          3  ...                      34
# 527                          Essonne          5  ...                      76
# 528                            Yonne          2  ...                       0
# 529                           Vosges          1  ...                     194
# 530                       Val-d'Oise          2  ...                      55
# 531                         Ardennes          3  ...                       8
# 532                         Bas-Rhin          2  ...                    1472
# 533                             Oise          4  ...                     521
# 534                         Bas-Rhin          4  ...                      61
# 535                   Seine-Maritime          3  ...                     211
# 536                          Moselle          7  ...                       9
# 537                 Bouches-du-Rhône          8  ...                      40
# 538            Territoire de Belfort          2  ...                      39
#
#      hemicycle_interventions_courtes  amendements_proposes amendements_signes  \
# 0                                307                    19               1736
# 1                                  8                    14                362
# 2                                  9                   186               2309
# 3                                  0                    15                581
# 4                                  7                    74                687
# 5                                  1                    14                394
# 6                                  1                    14                541
# 7                                  2                    18                485
# 8                                  1                     8                334
# 9                                  0                    16                574
# 10                                 0                     5                425
# 11                                94                   600               7380
# 12                                 1                    54                790
# 13                                 1                     2                435
# 14                                 1                     9                616
# 15                               239                   269               2585
# 16                                77                   143               1526
# 17                               168                  2635               5276
# 18                                26                    53                451
# 19                                42                   258               3679
# 20                                10                     2                290
# 21                                 5                   115               1694
# 22                                 5                    37                831
# 23                               453                    81                847
# 24                                 5                    78                817
# 25                                 0                     1                514
# 26                                 6                   143                741
# 27                                 0                    34               1298
# 28                                72                   136                435
# 29                               140                   161               3746
# ..                               ...                   ...                ...
# 509                                0                    69               3833
# 510                               24                   242               4335
# 511                                0                    24                449
# 512                              359                   968               3783
# 513                                6                    19               1262
# 514                               60                   155               2911
# 515                                9                    77                871
# 516                                0                    12                618
# 517                              236                   123                660
# 518                               32                   254               4646
# 519                                2                    39               1268
# 520                                4                    17                683
# 521                                8                    94               3670
# 522                                2                    39                549
# 523                              194                   192               2066
# 524                              121                   184               2844
# 525                                0                    22               1444
# 526                                6                    11                544
# 527                               12                    98                974
# 528                                0                     2               1157
# 529                               38                   526               3216
# 530                                8                    21                387
# 531                                9                    13               1229
# 532                             5966                     1                667
# 533                              162                   201                514
# 534                                6                   249               1581
# 535                              143                   895               2776
# 536                                3                    25                475
# 537                               37                   105               1111
# 538                               11                    18               1603
#
#     amendements_adoptes rapports  propositions_ecrites  propositions_signees  \
# 0                    63        0                     0                    25
# 1                   196        0                     0                     3
# 2                    89        0                     0                     4
# 3                   175        0                     0                     4
# 4                   225        0                     0                     4
# 5                   200        0                     0                     4
# 6                   191        0                     0                     4
# 7                   163        0                     0                     3
# 8                   144        0                     0                     3
# 9                   197        1                     0                     4
# 10                  213        0                     0                     3
# 11                  213        0                     2                    34
# 12                  171        0                     0                     4
# 13                  193        0                     0                     4
# 14                  204        0                     0                     3
# 15                   61        0                     0                    13
# 16                   63        0                     1                    10
# 17                   38        0                     0                    14
# 18                  242        0                     0                     5
# 19                  158        0                     0                     7
# 20                  146        0                     0                     3
# 21                  174        0                     0                     3
# 22                  224        0                     0                     3
# 23                  194        1                     0                     2
# 24                  165        0                     0                     0
# 25                  162        0                     0                     3
# 26                  155        0                     0                     5
# 27                   32        0                     0                    13
# 28                   25        0                     0                     2
# 29                  170        0                     0                     5
# ..                  ...      ...                   ...                   ...
# 509                 161        0                     0                     6
# 510                  91        0                     0                    15
# 511                 168        0                     0                     4
# 512                 158        1                     1                     8
# 513                 265        0                     0                     4
# 514                  73        0                     0                    17
# 515                 155        0                     0                     1
# 516                 190        0                     0                     4
# 517                 297        0                     0                     4
# 518                 137        0                     0                    34
# 519                  45        0                     0                    16
# 520                 139        0                     0                     0
# 521                 168        0                     0                     8
# 522                 209        0                     0                     3
# 523                  93        0                     1                     5
# 524                  63        0                     0                     4
# 525                 282        0                     0                     6
# 526                 209        0                     0                     3
# 527                 152        1                     0                     4
# 528                  36        0                     0                     1
# 529                  92        0                     4                    16
# 530                 222        0                     0                     4
# 531                  41        0                     2                     7
# 532                 138        0                     0                     1
# 533                  27        1                     1                     3
# 534                 157        0                     0                     3
# 535                  70        0                     0                     8
# 536                 214        0                     0                     4
# 537                 279        0                     0                     4
# 538                  61        0                     0                     3
#
#     questions_ecrites  questions_orales
# 0                  38                 9
# 1                   3                 0
# 2                  22                 3
# 3                   1                 0
# 4                  10                 2
# 5                   0                 1
# 6                  19                 0
# 7                   2                 4
# 8                   0                 0
# 9                  16                 2
# 10                  2                 3
# 11                 44                 4
# 12                 28                 1
# 13                 14                 0
# 14                 10                 5
# 15                 18                 7
# 16                  7                 6
# 17                 38                 8
# 18                  0                 1
# 19                 12                 5
# 20                  0                 1
# 21                 13                 3
# 22                  1                 0
# 23                  4                 3
# 24                  6                 6
# 25                 16                 0
# 26                  4                 4
# 27                  5                 2
# 28                 10                 2
# 29                 20                 8
# ..                ...               ...
# 509                 0                 1
# 510                36                 3
# 511                64                 1
# 512                26                 9
# 513                 8                 0
# 514                30                 8
# 515                 4                 6
# 516                15                 0
# 517                 3                 1
# 518                26                10
# 519                10                 2
# 520                 0                 3
# 521                10                10
# 522                 3                 3
# 523                 1                13
# 524                28                 5
# 525                55                 0
# 526                54                 2
# 527                10                 0
# 528                 0                 0
# 529                34                 7
# 530                14                 0
# 531                41                 5
# 532                23                 2
# 533                13                 4
# 534                14                 3
# 535                35                16
# 536                12                 0
# 537                52                 4
# 538                15                 4
#
# [539 rows x 40 columns]

# %% [markdown]
# ### 2. Nettoyage des données
#
# <p style="text-align:justify";>On commence par analyser les variables présentes dans la base afin de sélectionner celles que nous pouvons éliminer dans le cadre de notre étude.

# %%
df.columns # On affiche la liste des variables.
# Out:
# Index(['id', 'nom', 'nom_de_famille', 'prenom', 'sexe', 'date_naissance',
#        'lieu_naissance', 'num_deptmt', 'nom_circo', 'num_circo',
#        'mandat_debut', 'mandat_fin', 'ancien_depute', 'groupe_sigle',
#        'parti_ratt_financier', 'sites_web', 'emails', 'anciens_mandats',
#        'profession', 'place_en_hemicycle', 'url_an', 'id_an', 'slug',
#        'url_nosdeputes', 'url_nosdeputes_api', 'nb_mandats', 'twitter',
#        'semaines_presence', 'commission_presences', 'commission_interventions',
#        'hemicycle_interventions', 'hemicycle_interventions_courtes',
#        'amendements_proposes', 'amendements_signes', 'amendements_adoptes',
#        'rapports', 'propositions_ecrites', 'propositions_signees',
#        'questions_ecrites', 'questions_orales'],
#       dtype='object')

# %%
# On retire les variables que l'on juge inutiles pour notre étude.
df_new = df.drop(['id', 'nom_de_famille', 'prenom', 'lieu_naissance',
              'mandat_debut', 'mandat_fin', 'ancien_depute', 'sites_web',
              'emails', 'anciens_mandats', 'place_en_hemicycle', 'url_an',
              'id_an', 'slug', 'url_nosdeputes', 'url_nosdeputes_api', 'twitter'], axis=1)

# %% [markdown]
# <p style="text-align:justify";>On crée désormais une variable âge à partir de la variable date_naissance, en considérant que l'âge des députés est arrêté au 31 décembre 2020. Cela va nous permettre de répartir les députés en tranches d'âge de façon à analyser l'influence de l'âge sur l'assiduité.

# %%
df_new['age'] = 0 # On initialise à 0 la valeur de la variable age pour chaque individu.
for i in range(len(df_new)) :
    df_new['age'][i] = 2020 - int((df_new.iloc[i,2])[0:4]) 
    # On calcule la différence entre l'année actuelle et l'année de naissance de chaque député.

df_new = df_new.sort_values("age") # On réordonne la base dans l'ordre croissant de l'âge des députés. 

# On répartit maintenant les députés dans différentes tranches d'âge. 
df_new['tranche_age'] = 0
for i in range(len(df_new)) :
    if 20 <= df_new['age'][i] < 30 :
        df_new['tranche_age'][i] = '20-30 ans'
    if 30 <= df_new['age'][i] < 40 :
        df_new['tranche_age'][i] = '30-40 ans'
    if 40 <= df_new['age'][i] < 50 :
        df_new['tranche_age'][i] = '40-50 ans'
    if 50 <= df_new['age'][i] < 60 :
        df_new['tranche_age'][i] = '50-60 ans'
    if 60 <= df_new['age'][i] < 70 :
        df_new['tranche_age'][i] = '60-70 ans'
    if df_new['age'][i] >= 70 :
        df_new['tranche_age'][i] = '+ de 70 ans'
# Out:
# C:\Users\theop\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\theop\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# C:\Users\theop\Anaconda3\lib\site-packages\pandas\core\indexing.py:190: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)
# C:\Users\theop\Anaconda3\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\theop\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\theop\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\theop\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\theop\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# <p style="text-align:justify";>On poursuit le nettoyage en remplacant la modalité "0" de la variable profession par la modalité "Aucune", pour des questions de lisibilité.

# %%
for i in range(len(df_new)) :
    if df_new['profession'][i] == '0' :
        df_new['profession'][i] = 'Aucune'
df_new['profession'].head()
# Out:
# C:\Users\theop\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 139                                 Juriste
# 383                                  Aucune
# 3      Cadre supérieur (entreprises privée)
# 241                    Conseiller juridique
# 298     Agriculteur-propriétaire exploitant
# Name: profession, dtype: object

# %% [markdown]
# <p style="text-align:justify";>Par webscraping, on récupère désormais un tableau permettant de savoir si le député est un sortant, et on complète alors notre jeu de données.

# %%
# à faire

# %% [markdown]
# ## II. Analyse descriptive
#
# <p style="text-align:justify";>On procède à une analyse descriptive des données afin d'identifier les premières grandes tendances qui guideront notre travail. Les boîtes à moustaches (ou boîtes de Tukey, ou boxplots en anglais) permettent par exemple d'étudier les statistiques liées aux semaines de présence des députés à l'Assemblée nationale, en distinguant selon le sexe, le parti politique ou encore l'âge. On utilise ici la librairie seaborn.

# %%
plt.figure(figsize=(15,10))
sns.set_style("whitegrid")
ax = sns.boxplot(x=df_new["semaines_presence"])
plt.xlabel("Semaines de présence à l'Assemblée nationale",size=15)
plt.title("Boxplot représentant le nombre de semaines de présence des députés",size=20,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Boxplot représentant le nombre de semaines de présence des députés')

# %%
plt.figure(figsize=(15,10))
ax = sns.boxplot(x="sexe", y="semaines_presence", data=df_new)
plt.xlabel("Sexe",size=15)
plt.ylabel("Semaines de présence à l'Assemblée nationale",size=15)
plt.title("Boxplot représentant le nombre de semaines de présence des députés en fonction de leur sexe",size=20,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Boxplot représentant le nombre de semaines de présence des députés en fonction de leur sexe')

# %%
plt.figure(figsize=(15,10))
ax = sns.boxplot(x="groupe_sigle", y="semaines_presence", data=df_new)
plt.xlabel("Parti politique",size=15)
plt.ylabel("Semaines de présence à l'Assemblée nationale",size=15)
plt.title("Boxplot représentant le nombre de semaines de présence des députés en fonction de leur parti",size=20,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Boxplot représentant le nombre de semaines de présence des députés en fonction de leur parti')

# %%
plt.figure(figsize=(15,10))
ax = sns.boxplot(x="tranche_age", y="semaines_presence", data=df_new)
plt.xlabel("Tranche d'âge",size=15)
plt.ylabel("Semaines de présence à l'Assemblée nationale",size=15)
plt.title("Boxplot représentant le nombre de semaines de présence des députés en fonction de leur âge",size=20,fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Boxplot représentant le nombre de semaines de présence des députés en fonction de leur âge')

# %% [markdown]
# L'observation de ces boîtes à moustaches donne à voir quelques premières tendances :
# - certains députés se démarquent de l'immense majorité des autres députés par un très fort absentéisme, comme le montrent les valeurs extrêmes du premier graphique ;
# - globalement, les hommes sont légèrement plus présents à l'Assemblée nationale que les femmes ;
# - il y a d'assez grandes disparités entre les différents partis ;
# - les députés les plus âgés semblent être les moins assidus, mais les plus jeunes présentent la médiane la plus faible ;
# - les 50-60 ans sont visiblement la génération la plus assidue.

# %% [markdown]
# ## Prochaines étapes :
# - trouver base avec variable "sortant", webscraper et joindre les deux bases
# - compléter avec d'autres stats desc (carte ? autre graphique ?)
# - normaliser les données, puis réaliser la matrice de corrélation graphique / scatter-plot
# - déterminer variables intéressantes pour l'ACP
# - construire un score d'assiduité (réfléchir aux pondérations)
# - k-means clustering
# - régression linéaire
